# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/HOUSE_PRICING.csv")
data
# Out:
#    AREA  PRICE_LK
# 0   500        25
# 1   550        30
# 2   600        35
# 3   650        40
# 4   700        45
# 5   750        50
# 6   800        55
# 7   850        60
# 8   900        65
# 9  1000        70

# %%
data.size
# Out:
# 20

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AREA      10 non-null     int64
#  1   PRICE_LK  10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
data.describe()
# Out:
#               AREA   PRICE_LK
# count    10.000000  10.000000
# mean    730.000000  47.500000
# std     160.208198  15.138252
# min     500.000000  25.000000
# 25%     612.500000  36.250000
# 50%     725.000000  47.500000
# 75%     837.500000  58.750000
# max    1000.000000  70.000000

# %%
data.shape
# Out:
# (10, 2)

# %%
X = data[['AREA']]
y = data[['PRICE_LK']]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (Lakhs)")
plt.title("AREA vs PRICE")
plt.legend()
plt.grid(True)
plt.show()

# %%
new_area = pd.DataFrame({'AREA': [875]})
predicted_price = model.predict(new_area)
print(f"{predicted_price[0][0]:.2f} Lakhs")
# Out:
# 61.15 Lakhs

# %%
from sklearn.metrics import r2_score, accuracy_score
accuracy = model.score(X, y)
r2 = r2_score(y, y_pred)
print(f"Accuracy (R^2 Score): {accuracy:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Accuracy (R^2 Score): 0.99
# R^2 Score: 0.99

# %%
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 1.46
